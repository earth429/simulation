# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("kadai8-1.csv",header=None)
df = df.rename(columns={0:"step",1:"Q",2:"I"})
df.head()
# Out:
#       step          Q         I
# 0  0.00000  10.000000  0.000000
# 1  0.03125  10.000000 -0.104167
# 2  0.06250   9.996694 -0.208316
# 3  0.09375   9.990082 -0.312415
# 4  0.12500   9.980167 -0.416427

# %%
plt.figure(figsize=(6,4),dpi=200,facecolor="white")
plt.tick_params(direction='in',#目盛り内側
                pad =10, #目盛りとラベルの距離
                length=7.5, #目盛りの長さ
                width=1.5, #目盛りの幅
                labelsize=12,
               )
plt.plot(df["step"],df["Q"],label="Q",linewidth=3,marker="x")
plt.plot(df["step"],df["I"],label="I",linewidth=3,marker="o")
plt.xlabel("$t$",fontsize=15)
plt.ylabel("$Q or I$",fontsize=15)
plt.legend()
plt.savefig("kadai7-4.pdf")
