# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
h1 = pd.read_csv("./csv/Euler01.csv",header=None, names=['x', 'y'])
#h1 値が確認できる
# Out:
#      x         y
# 0  0.1  1.100000
# 1  0.2  1.210000
# 2  0.3  1.331000
# 3  0.4  1.464100
# 4  0.5  1.610510
# 5  0.6  1.771561
# 6  0.7  1.948717
# 7  0.8  2.143589
# 8  0.9  2.357948
# 9  1.0  2.593742

# %%
h2 = pd.read_csv("./csv/Euler02.csv",header=None, names=['x', 'y'])
#h2
# Out:
#      x        y
# 0  0.2  1.20000
# 1  0.4  1.44000
# 2  0.6  1.72800
# 3  0.8  2.07360
# 4  1.0  2.48832

# %%
h05 = pd.read_csv("./csv/Euler005.csv",header=None, names=['x', 'y'])
#h05
# Out:
#        x         y
# 0   0.05  1.050000
# 1   0.10  1.102500
# 2   0.15  1.157625
# 3   0.20  1.215506
# 4   0.25  1.276282
# 5   0.30  1.340096
# 6   0.35  1.407100
# 7   0.40  1.477455
# 8   0.45  1.551328
# 9   0.50  1.628895
# 10  0.55  1.710339
# 11  0.60  1.795856
# 12  0.65  1.885649
# 13  0.70  1.979932
# 14  0.75  2.078928
# 15  0.80  2.182875
# 16  0.85  2.292018
# 17  0.90  2.406619
# 18  0.95  2.526950
# 19  1.00  2.653298

# %%
h5 = pd.read_csv("./csv/Euler05.csv",header=None, names=['x', 'y'])
#h5
# Out:
#      x     y
# 0  0.0  1.00
# 1  0.5  1.50
# 2  1.0  2.25

# %%
truth_x = np.linspace(-0.5,1.5,1000)
truth_y = np.e**(truth_x)
plt.figure(facecolor="white")
plt.tick_params(direction='in',#目盛り内側
                pad =10, #目盛りとラベルの距離
                length=7.5, #目盛りの長さ
                width=1.5, #目盛りの幅
                labelsize=12,
               )
plt.plot(truth_x,truth_y,label="$u = e^t$",linewidth = 3.0)
plt.scatter(h05["x"],h05["y"],label="$h= 0.05$",marker="x",s=100)
plt.scatter(h1["x"],h1["y"],label="$h= 0.1$",s=100)
plt.scatter(h2["x"],h2["y"],label="$h= 0.2$",marker="s",s=100)
plt.scatter(h5["x"],h5["y"],label="$h= 0.5$",marker="^",s=100)
plt.xlabel("$t$",fontsize=13)
plt.ylabel("$u$",fontsize=13)
plt.xlim(-0.1,1.1)
plt.ylim(0.8,3)
plt.legend()
plt.title("Euler method")
plt.savefig("Euler.pdf")
