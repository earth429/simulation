# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("kadai7-3.csv",header=None)
df = df.rename(columns={0:"step",1:"y1",2:"y2"})
df.head()
# Out:
#        step         y1        y2
# 0  0.000000  10.000000  0.000000
# 1  0.015625  10.000000 -0.156250
# 2  0.031250   9.997559 -0.305176
# 3  0.046875   9.992790 -0.447083
# 4  0.062500   9.985805 -0.582263

# %%
plt.figure(figsize=(6,4),dpi=200,facecolor="white")
plt.tick_params(direction='in',#目盛り内側
                pad =10, #目盛りとラベルの距離
                length=7.5, #目盛りの長さ
                width=1.5, #目盛りの幅
                labelsize=12,
               )
plt.plot(df["step"],df["y1"],label="$y_1$",linewidth=3,marker="x")
plt.plot(df["step"],df["y2"],label="$y_2$",linewidth=3,marker="o")
plt.xlabel("$t$",fontsize=15)
plt.ylabel("$u$",fontsize=15)
plt.legend()
plt.savefig("kadai7-3.pdf")
